# %%
import pandas as pd

# %%
fgk = pd.read_csv('data/fgk.txt', sep="\t")
fgk.head()
# Out:
#         star            group              ID              ID_alt star_alt1  \
# 0  HIP101345  G Subgiant (IV)  HD195564_HAR_1   HIP101345_HARPS_1  HD195564
# 1  HIP101345  G Subgiant (IV)  HD195564_NAR_1  HIP101345_NARVAL_1  HD195564
# 2   HIP10234    K Giant (III)   HD13468_FER_1    HIP10234_FEROS_1   HD13468
# 3   HIP10234    K Giant (III)   HD13468_HAR_1    HIP10234_HARPS_1   HD13468
# 4  HIP102422  K Subgiant (IV)  HD198149_NAR_1  HIP102422_NARVAL_1  HD198149
#
#   star_alt2  origin  snr      R    Rmax  ...  e[Ti 1/H]  n[Ti 1/H]  [Ti 2/H]  \
# 0         -   HARPS  902  42000  115000  ...      0.023         34     0.062
# 1         -  NARVAL  369  42000   68000  ...      0.023         34     0.062
# 2         -   FEROS  121  42000   48000  ...      0.059         36    -0.221
# 3         -   HARPS   95  42000  115000  ...      0.059         36    -0.221
# 4         -  NARVAL  908  42000   68000  ...      0.062         35    -0.218
#
# ...

# %%
fgk.origin.value_counts()
# Out:
# origin
# ELODIE      113
# NARVAL      104
# HARPS        84
# UVES         65
# ESPADONS     58
# HERMES       39
# FEROS        35
# FIES         17
# CAFE          6
# Name: count, dtype: int64

# %%
fgk[fgk.origin=='ELODIE'].head()
# Out:
#           star          group              ID              ID_alt star_alt1  \
# 28   HIP112731  K Giant (III)  HD216174_ELO_1  HIP112731_ELODIE_1  HD216174
# 39   HIP114971  K Giant (III)  HD219615_ELO_1  HIP114971_ELODIE_1  HD219615
# 235   HIP57939    G Dwarf (V)  HD103095_ELO_1   HIP57939_ELODIE_1  HD103095
# 266   HIP69673  K Giant (III)  HD124897_ELO_1   HIP69673_ELODIE_1  HD124897
# 343   HIP88348    G Dwarf (V)  HD164922_ELO_1   HIP88348_ELODIE_1  HD164922
#
#     star_alt2  origin  snr      R   Rmax  ...  e[Ti 1/H]  n[Ti 1/H]  [Ti 2/H]  \
# 28          -  ELODIE  204  42000  45000  ...      0.108         28    -0.297
# 39          -  ELODIE  143  42000  45000  ...      0.057         38    -0.233
# 235   Gmb1830  ELODIE  359  42000  45000  ...      0.090         31    -1.024
# 266  Arcturus  ELODIE  902  42000  45000  ...      0.070         53    -0.332
# 343         -  ELODIE  655  42000  45000  ...      0.032         51     0.162
#
# ...

# %%
from spectra_download.sources import ElodieSource


elodie_source = ElodieSource()
elodie_source.download('HD 181420', raw_save_path='data/spectra/elodie', zarr_paths='data/spectra/elodie.zarr')
# Out:
# [SpectrumRecord(spectrum_id='elodie:20010702/0019', source='elodie', metadata={'identifier': 'HD 181420', 'product': 'spectrum', 'access_url': 'http://atlas.obs-hp.fr/elodie/fE.cgi?n=e500&c=i&z=s1d&a=mime:application/fits&o=elodie:20010702/0019', 'save_name': 'HD_181420.fits', '_spec_index': 1, '_spec_total': 1, 'raw_path': 'data/spectra/elodie/HD_181420.fits', 'zarr_store': 'data/spectra/elodie.zarr', 'zarr_key': 'spectra/HD_181420'}),
#  SpectrumRecord(spectrum_id='CC.cgi', source='elodie', metadata={'identifier': 'HD 181420', 'product': 'ccf', 'access_url': 'http://atlas.obs-hp.fr/elodie/CC.cgi?c=i&dataset=20010702&imanum=0019&masque=R37000K0&type=obj', 'save_name': 'HD_181420_ccf_1.fits', '_ccf_index': 1, '_ccf_total': 2, 'raw_path': 'data/spectra/elodie/HD_181420_ccf_1.fits', 'zarr_store': 'data/spectra/elodie.zarr', 'zarr_key': 'spectra/HD_181420'}),
# ...

# %%
from astropy.io import fits


f = fits.open('data/spectra/elodie/HD_181420.fits')
f[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / No.Bits per pixel
# NAXIS   =                    1 / number of data axes
# NAXIS1  =                56000 / length of data axis 1
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# ...

# %%
import zarr

# %%
elodie_s = zarr.open_group('data/spectra/elodie.zarr')

# %%
elodie_s.tree()
# Out:
# /
# └── spectra
#     └── HD_181420
#         ├── ccf (2, 141) float64
#         ├── error (1, 56000) float64
#         ├── intensity (1, 56000) float64
#         └── wavelengths (1, 56000) float64

# %%
elodie_s
