# %%
import zarr

# %%
spectra = zarr.open_group('fgk_spectra_all.zarr')

# %%
spectra['spectra'].info_complete()
# Out:
# Name        : spectra
# Type        : Group
# Zarr format : 3
# Read-only   : False
# Store type  : LocalStore
# No. members : 3515
# No. arrays  : 2604
# No. groups  : 911

# %%
spectra.tree()
# Out:
# /
# ├── metadata
# │   ├── ELODIE
# │   │   ├── HD216174
# │   │   ├── HD219615
# │   │   ├── HIP112731
# │   │   └── HIP114971
# │   ├── HARPS
# │   │   ├── HD195564
# │   │   ├── HD210027
# │   │   ├── HD29139
# │   │   └── HD49933
# │   └── HERMES
# │       ├── HD1671
# │       ├── HD16765
# │       ├── HD17709
# │       ├── HD17824
# │       ├── HD18784
# │       ├── HD200205
# │       ├── HD211388
# │       ├── HD214868
# │       ├── HD216174
# │       ├── HD22798
# │       ├── HD23526
# │       ├── HD2665
# │       ├── HD30504
# │       ├── HD30814
# │       ├── HD3546
# │       ├── HD48737
# │       ├── HIP103598
# │       ├── HIP109937
# │       ├── HIP111944
# │       ├── HIP112731
# │       ├── HIP12530
# │       ├── HIP13288
# │       ├── HIP13328
# │       ├── HIP14060
# │       ├── HIP1686
# │       ├── HIP17086
# │       ├── HIP17595
# │       ├── HIP22453
# │       ├── HIP22479
# │       ├── HIP2413
# │       ├── HIP3031
# │       └── HIP32362
# └── spectra
# ...
